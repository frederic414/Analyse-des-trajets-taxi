# %%
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()


# Define the connection information to the database
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD') 
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')
# Create a connection to the database
engine = create_engine(f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')
# Name of the table to read
table_name = 'ytaxi_histo'
# Read data from the table into a DataFrame
df = pd.read_sql_table(table_name, con=engine)
# Display the first few rows of the DataFrame
df
# Out:
#         vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              1  2018-01-01 00:21:05   2018-01-01 00:24:23                1
# 1              1  2018-01-01 00:44:55   2018-01-01 01:03:05                1
# 2              1  2018-01-01 00:08:26   2018-01-01 00:14:21                2
# 3              1  2018-01-01 00:20:22   2018-01-01 00:52:51                1
# 4              1  2018-01-01 00:09:18   2018-01-01 00:27:06                2
# ...          ...                  ...                   ...              ...
# 675995         1  2018-01-03 19:38:44   2018-01-03 19:48:07                1
# 675996         1  2018-01-03 19:05:08   2018-01-03 19:14:53                2
# 675997         1  2018-01-03 19:23:36   2018-01-03 19:32:27                1
# 675998         1  2018-01-03 19:38:34   2018-01-03 19:46:36                1
# 675999         1  2018-01-03 19:48:57   2018-01-03 19:54:11                2
#
#         trip_distance  ratecodeid store_and_fwd_flag  pulocationid  \
# 0                 0.5           1                  N            41
# 1                 2.7           1                  N           239
# 2                 0.8           1                  N           262
# 3                10.2           1                  N           140
# 4                 2.5           1                  N           246
# ...               ...         ...                ...           ...
# 675995            1.5           1                  N           100
# 675996            1.8           1                  N           161
# 675997            2.0           1                  N            43
# 675998            1.7           1                  N           142
# 675999            0.6           1                  N           238
#
#         dolocationid  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 24             2          4.5    0.5      0.5        0.00
# 1                140             2         14.0    0.5      0.5        0.00
# 2                141             1          6.0    0.5      0.5        1.00
# 3                257             2         33.5    0.5      0.5        0.00
# 4                239             1         12.5    0.5      0.5        2.75
# ...              ...           ...          ...    ...      ...         ...
# 675995           229             2          8.0    1.0      0.5        0.00
# 675996           263             1          9.0    1.0      0.5        2.15
# 675997           142             1          9.0    1.0      0.5        0.00
# 675998           238             1          8.0    1.0      0.5        1.96
# 675999           238             1          5.0    1.0      0.5        1.35
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 0                0.0                    0.3          5.80
# 1                0.0                    0.3         15.30
# 2                0.0                    0.3          8.30
# 3                0.0                    0.3         34.80
# 4                0.0                    0.3         16.55
# ...              ...                    ...           ...
# 675995           0.0                    0.3          9.80
# 675996           0.0                    0.3         12.95
# 675997           0.0                    0.3         10.80
# 675998           0.0                    0.3         11.76
# 675999           0.0                    0.3          8.15
#
#         congestion_surcharge  airport_fee
# 0                        NaN          NaN
# 1                        NaN          NaN
# 2                        NaN          NaN
# 3                        NaN          NaN
# 4                        NaN          NaN
# ...                      ...          ...
# 675995                   NaN          NaN
# 675996                   NaN          NaN
# 675997                   NaN          NaN
# 675998                   NaN          NaN
# 675999                   NaN          NaN
#
# [676000 rows x 19 columns]

# %%
from download_data_taxi import download_histo_data
# Path to save data
path_to_save_data = r"D:\Lab\projet ETL\data"
# Function call
download_histo_data(path_to_save_data)
# Out:
# https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2018-02-01 00:01:58   2018-02-01 00:04:03                1
# 1               1  2018-02-01 00:56:48   2018-02-01 00:57:42                1
# 2               1  2018-02-01 00:04:42   2018-02-01 00:19:32                1
# 3               1  2018-02-01 00:38:10   2018-02-01 00:40:16                1
# 4               1  2018-02-01 00:43:03   2018-02-01 00:59:26                2
# ...           ...                  ...                   ...              ...
# 8492814         2  2018-02-28 23:21:56   2018-02-28 23:47:43                6
# 8492815         2  2018-02-28 23:54:07   2018-03-01 00:24:56                6
# 8492816         2  2018-02-28 23:17:42   2018-02-28 23:53:11                1
# 8492817         2  2018-03-01 13:39:17   2018-03-01 13:49:08                2
# 8492818         2  2018-02-28 23:03:18   2018-02-28 23:03:24                1
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 0.00           1                  N           145
# 1                 2.90           1                  N           145
# 2                 5.80           1                  N           236
# 3                 0.30           1                  N            82
# 4                 2.60           1                  N            82
# ...                ...         ...                ...           ...
# 8492814           9.61           1                  N           138
# 8492815           4.20           1                  N           230
# 8492816           0.00           1                  N           193
# 8492817           0.00           1                  N           264
# 8492818           0.00           1                  N           264
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 145             2          3.5    0.5      0.5         0.0
# 1                 145             2          2.5    0.5      0.5         0.0
# 2                 119             2         18.5    0.5      0.5         0.0
# 3                  82             2          3.5    0.5      0.5         0.0
# 4                   7             1         13.0    0.5      0.5         1.0
# ...               ...           ...          ...    ...      ...         ...
# 8492814           163             2         28.5    0.5      0.5         0.0
# 8492815           230             1         21.5    0.5      0.5         0.0
# 8492816           193             2          0.0    0.0      0.0         0.0
# 8492817           264             2          2.4    0.0      0.5         0.0
# 8492818           193             1          0.0    0.0      0.0         0.0
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3          4.80
# 1                0.00                    0.3          3.80
# 2                0.00                    0.3         19.80
# 3                0.00                    0.3          4.80
# 4                0.00                    0.3         15.30
# ...               ...                    ...           ...
# 8492814          5.54                    0.3         35.34
# 8492815          0.00                    0.3         22.80
# 8492816          0.00                    0.0          0.00
# 8492817          0.00                    0.3          3.20
# 8492818          0.00                    0.0          0.00
#
#         congestion_surcharge airport_fee
# 0                       None        None
# 1                       None        None
# 2                       None        None
# 3                       None        None
# 4                       None        None
# ...                      ...         ...
# 8492814                 None        None
# 8492815                 None        None
# 8492816                 None        None
# 8492817                 None        None
# 8492818                 None        None
#
# [8492819 rows x 19 columns]

# %%
valeurs_manquantes = data.isnull().sum()

valeurs_manquantes
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count                0
# trip_distance                  0
# RatecodeID                     0
# store_and_fwd_flag             0
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge     8492819
# airport_fee              8492819
# dtype: int64
